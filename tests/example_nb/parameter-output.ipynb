# %%
mrk = 'Mrk 421' # oda:AstrophysicalObject
flout = 4.2 # oda:Float
intout = 4 # oda:Integer
timeinst = 56457.0 # oda:TimeInstantMJD
timeisot = '2022-10-09T13:00:00' # oda:TimeInstantISOT
wrng = 'FOO' # oda:PhotometricBand 
            # NOTE: as with input parameters, plugin accepts wrongly-annotated parameters as general-type ones
            # TODO: validation somewhere (by the bot with PR?).
